# %% [markdown]
# # Getting started with PPO and ProcGen

# %% [markdown]
# Here's a bit of code that should help you get started on your projects.
#
# The cell below installs `procgen` and downloads a small `utils.py` script that contains some utility functions. You may want to inspect the file for more details.

# %%
# !pip install procgen
# !wget https://raw.githubusercontent.com/nicklashansen/ppo-procgen-utils/main/utils.py
# Out:
# Collecting procgen
#   Downloading https://files.pythonhosted.org/packages/d6/34/0ae32b01ec623cd822752e567962cfa16ae9c6d6ba2208f3445c017a121b/procgen-0.10.4-cp36-cp36m-manylinux2010_x86_64.whl (39.9MB)
#      |████████████████████████████████| 39.9MB 84kB/s
# Requirement already satisfied: filelock<4.0.0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from procgen) (3.0.12)
# Requirement already satisfied: gym<1.0.0,>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from procgen) (0.17.3)
# Collecting gym3<1.0.0,>=0.3.3
#   Downloading https://files.pythonhosted.org/packages/89/8c/83da801207f50acfd262041e7974f3b42a0e5edd410149d8a70fd4ad2e70/gym3-0.3.3-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 8.4MB/s
# Requirement already satisfied: numpy<2.0.0,>=1.17.0 in /usr/local/lib/python3.6/dist-packages (from procgen) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym<1.0.0,>=0.15.0->procgen) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym<1.0.0,>=0.15.0->procgen) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym<1.0.0,>=0.15.0->procgen) (1.5.0)
# Requirement already satisfied: cffi<2.0.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from gym3<1.0.0,>=0.3.3->procgen) (1.14.3)
# Collecting imageio-ffmpeg<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/1b/12/01126a2fb737b23461d7dadad3b8abd51ad6210f979ff05c6fa9812dfbbe/imageio_ffmpeg-0.3.0-py3-none-manylinux2010_x86_64.whl (22.2MB)
#      |████████████████████████████████| 22.2MB 75.4MB/s
# Collecting moderngl<6.0.0,>=5.5.4
#   Downloading https://files.pythonhosted.org/packages/56/ab/5f72a1b7c5bdbb17160c85e8ba855d48925c74ff93c1e1027d5ad40bf33c/moderngl-5.6.2-cp36-cp36m-manylinux1_x86_64.whl (664kB)
#      |████████████████████████████████| 665kB 42.4MB/s
# Collecting glfw<2.0.0,>=1.8.6
#   Downloading https://files.pythonhosted.org/packages/74/1b/cc758368f1b2466b3701c0f692973aa8a0b51a192a40463c1d02d54d640c/glfw-1.12.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (203kB)
#      |████████████████████████████████| 204kB 53.3MB/s
# Collecting imageio<3.0.0,>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/6e/57/5d899fae74c1752f52869b613a8210a2480e1a69688e65df6cb26117d45d/imageio-2.9.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 48.0MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<1.0.0,>=0.15.0->procgen) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi<2.0.0,>=1.13.0->gym3<1.0.0,>=0.3.3->procgen) (2.20)
# Collecting glcontext<3,>=2
#   Downloading https://files.pythonhosted.org/packages/b0/8d/93915df9cd8d31c5f054bbacd1c7a76cd2f776b8212dcc768358bd2d4a37/glcontext-2.2.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio<3.0.0,>=2.6.0->gym3<1.0.0,>=0.3.3->procgen) (7.0.0)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: imageio-ffmpeg, glcontext, moderngl, glfw, imageio, gym3, procgen
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
# Successfully installed glcontext-2.2.0 glfw-1.12.0 gym3-0.3.3 imageio-2.9.0 imageio-ffmpeg-0.3.0 moderngl-5.6.2 procgen-0.10.4
# --2020-12-06 10:17:12--  https://raw.githubusercontent.com/nicklashansen/ppo-procgen-utils/main/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14807 (14K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]  14.46K  --.-KB/s    in 0s
#
# 2020-12-06 10:17:12 (153 MB/s) - ‘utils.py’ saved [14807/14807]

# %% [markdown]
# Hyperparameters. These values should be a good starting point. You can modify them later once you have a working implementation.

# %%
# Hyperparameters
total_steps = 10e6
num_envs = 32
num_levels = 100
num_steps = 256
num_epochs = 3
batch_size = 512
eps = .2
grad_eps = .5
value_coef = .5
entropy_coef = .01

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from utils import make_env, Storage, orthogonal_init

from google.colab import files

def xavier_uniform_init(module, gain=1.0):
    if isinstance(module, nn.Linear) or isinstance(module, nn.Conv2d):
        nn.init.xavier_uniform_(module.weight.data, gain)
        nn.init.constant_(module.bias.data, 0)
    return module



class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)



class ResidualBlock(nn.Module):
    def __init__(self,
                 in_channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=in_channels, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=in_channels, out_channels=in_channels, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        out = nn.ReLU()(x)
        out = self.conv1(out)
        out = nn.ReLU()(out)
        out = self.conv2(out)
        return out + x

class ImpalaBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ImpalaBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1, padding=1)
        self.res1 = ResidualBlock(out_channels)
        self.res2 = ResidualBlock(out_channels)

    def forward(self, x):
        x = self.conv(x)
        x = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)(x)
        x = self.res1(x)
        x = self.res2(x)
        return x

class ImpalaModel(nn.Module):
    def __init__(self,
                 in_channels,
                 **kwargs):
        super(ImpalaModel, self).__init__()
        self.block1 = ImpalaBlock(in_channels=in_channels, out_channels=16)
        self.block2 = ImpalaBlock(in_channels=16, out_channels=32)
        self.block3 = ImpalaBlock(in_channels=32, out_channels=32)
        self.fc = nn.Linear(in_features=32 * 8 * 8, out_features=256)

        self.output_dim = 256
        self.apply(xavier_uniform_init)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = nn.ReLU()(x)
        x = Flatten()(x)
        x = self.fc(x)
        x = nn.ReLU()(x)
        return x


class Encoder(nn.Module):
  def __init__(self, in_channels, feature_dim):
    super().__init__()
    self.layers = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=32, kernel_size=8, stride=4), nn.ReLU(),
        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2), nn.ReLU(),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1), nn.ReLU(),
        Flatten(),
        nn.Linear(in_features=1024, out_features=feature_dim), nn.ReLU()
    )
    self.apply(orthogonal_init)

  def forward(self, x):
    return self.layers(x)


class Policy(nn.Module):
  def __init__(self, encoder, feature_dim, num_actions):
    super().__init__()
    self.encoder = encoder
    self.policy = orthogonal_init(nn.Linear(feature_dim, num_actions), gain=.01)
    self.value = orthogonal_init(nn.Linear(feature_dim, 1), gain=1.)

  def act(self, x):
    with torch.no_grad():
      x = x.cuda().contiguous()
      dist, value = self.forward(x)
      action = dist.sample()
      log_prob = dist.log_prob(action)
    
    return action.cpu(), log_prob.cpu(), value.cpu()

  def forward(self, x):
    x = self.encoder(x)
    logits = self.policy(x)
    value = self.value(x).squeeze(1)
    dist = torch.distributions.Categorical(logits=logits)

    return dist, value

########################################################################################################################################

# Define environmentbossfight
# check the utils.py file for info on arguments
env = make_env(num_envs, num_levels=num_levels, use_backgrounds=True,env_name='starpilot')
print('Observation space:', env.observation_space)
print('Action space:', env.action_space.n)

# Define network
#encoder = Encoder(3,512)
observation_shape = env.observation_space.shape
in_channels = observation_shape[0]
encoder = ImpalaModel(in_channels=in_channels)
policy = Policy(encoder, 256, 15)
policy.cuda()
# Define optimizer
# these are reasonable values but probably not optimal
optimizer = torch.optim.Adam(policy.parameters(), lr=5e-4, eps=1e-5)

# Define temporary storage
# we use this to collect transitions during each iteration
storage = Storage(
    env.observation_space.shape,
    num_steps,
    num_envs
)


# Run training
obs = env.reset()
step = 0
print("NN setup, Training Starts")
while step < total_steps:

  # Use policy to collect data for num_steps steps
  policy.eval()
  for _ in range(num_steps):
    # Use policy
    action, log_prob, value = policy.act(obs)
    
    # Take step in environment
    next_obs, reward, done, info = env.step(action)

    # Store data
    storage.store(obs, action, reward, done, info, log_prob, value)
    
    # Update current observation
    obs = next_obs

  # Add the last observation to collected data
  _, _, value = policy.act(obs)
  storage.store_last(obs, value)

  # Compute return and advantage
  storage.compute_return_advantage()

  # Optimize policy
  policy.train()
  for epoch in range(num_epochs):

    # Iterate over batches of transitions
    generator = storage.get_generator(batch_size)
    for batch in generator:
      b_obs, b_action, b_log_prob, b_value, b_returns, b_advantage = batch

      # Get current policy outputs
      new_dist, new_value = policy(b_obs)
      new_log_prob = new_dist.log_prob(b_action)
      # log_prob
      # Clipped policy objective
      #print(str(log_prob.shape) + " " + str(b_log_prob.shape) + " " + str(new_log_prob.shape))
      ratio = torch.exp(new_log_prob - b_log_prob)
      
      clipped_ratio = ratio.clamp(min=1.0 - eps, max=1.0 + eps) 
      policy_reward = torch.min(ratio * b_advantage, clipped_ratio * b_advantage)
      #clip_fraction = (abs((ratio - 1.0)) > clip).to(torch.float).mean()
      pi_loss = -policy_reward.mean()

      # Clipped value function objective
      # clipped_value = new_value + (b_value - new_value).clamp(min=-eps,max=eps)
      # vf_loss=torch.max((b_value-b_returns)**2, (clipped_value-b_returns)**2)
      # value_loss = 0.5 * vf_loss.mean()

      # clipped_value = b_value + (new_value - b_value).clamp(min=-eps,max=eps) 

      # clipped_value = (new_value - b_value).clamp(min=-eps,max=eps)
      # value_loss = 0.5 * torch.max(torch.pow(new_value - b_returns,2), torch.pow(clipped_value - b_returns, 2)).mean()
      value_loss = 0.5 * torch.max(torch.pow(new_value - b_returns,2), torch.pow(b_value - b_returns, 2)).mean()

      # Entropy loss
      entropy_loss = new_dist.entropy().mean()

      # Backpropagate losses
      # loss = torch.mean(pi_loss+value_coef*value_loss+entropy_coef*entropy_loss) #
      loss = pi_loss + value_coef * value_loss - entropy_coef * entropy_loss
      loss.backward()

      # Clip gradients
      torch.nn.utils.clip_grad_norm_(policy.parameters(), grad_eps)

      # Update policy
      optimizer.step()
      optimizer.zero_grad()

  # Update stats
  step += num_envs * num_steps
  print(f'Step: {step}\tMean reward: {storage.get_reward()}')

print('Completed training!')
torch.save(policy.state_dict(), 'checkpoint.pt')

from google.colab import files
files.download('checkpoint.pt')
# Out:
# Observation space: Box(0.0, 1.0, (3, 64, 64), float32)
# Action space: 15
# NN setup, Training Starts
# Step: 8192	Mean reward: 3.65625
# Step: 16384	Mean reward: 5.3125
# Step: 24576	Mean reward: 5.71875
# Step: 32768	Mean reward: 6.34375
# Step: 40960	Mean reward: 5.375
# Step: 49152	Mean reward: 4.71875
# Step: 57344	Mean reward: 6.125
# Step: 65536	Mean reward: 7.3125
# Step: 73728	Mean reward: 5.59375
# Step: 81920	Mean reward: 7.0625
# Step: 90112	Mean reward: 6.09375
# Step: 98304	Mean reward: 6.5
# Step: 106496	Mean reward: 7.28125
# Step: 114688	Mean reward: 6.4375
# Step: 122880	Mean reward: 6.5
# Step: 131072	Mean reward: 5.8125
# Step: 139264	Mean reward: 6.28125
# Step: 147456	Mean reward: 7.28125
# Step: 155648	Mean reward: 7.15625
# Step: 163840	Mean reward: 7.40625
# Step: 172032	Mean reward: 7.59375
# Step: 180224	Mean reward: 6.71875
# Step: 188416	Mean reward: 7.4375
# Step: 196608	Mean reward: 7.75
# Step: 204800	Mean reward: 6.8125
# Step: 212992	Mean reward: 7.59375
# Step: 221184	Mean reward: 7.15625
# Step: 229376	Mean reward: 6.3125
# Step: 237568	Mean reward: 7.34375
# Step: 245760	Mean reward: 7.5625
# Step: 253952	Mean reward: 6.65625
# Step: 262144	Mean reward: 7.0625
# Step: 270336	Mean reward: 6.71875
# Step: 278528	Mean reward: 6.6875
# Step: 286720	Mean reward: 5.65625
# Step: 294912	Mean reward: 7.0
# Step: 303104	Mean reward: 7.1875
# Step: 311296	Mean reward: 7.1875
# Step: 319488	Mean reward: 7.59375
# Step: 327680	Mean reward: 7.125
# Step: 335872	Mean reward: 6.625
# Step: 344064	Mean reward: 6.84375
# Step: 352256	Mean reward: 7.15625
# Step: 360448	Mean reward: 7.625
# Step: 368640	Mean reward: 8.0
# Step: 376832	Mean reward: 6.71875
# Step: 385024	Mean reward: 7.3125
# Step: 393216	Mean reward: 7.3125
# Step: 401408	Mean reward: 7.78125
# Step: 409600	Mean reward: 7.84375
# Step: 417792	Mean reward: 7.53125
# Step: 425984	Mean reward: 7.875
# Step: 434176	Mean reward: 7.59375
# Step: 442368	Mean reward: 7.71875
# Step: 450560	Mean reward: 7.53125
# Step: 458752	Mean reward: 7.625
# Step: 466944	Mean reward: 7.09375
# Step: 475136	Mean reward: 6.875
# Step: 483328	Mean reward: 7.8125
# Step: 491520	Mean reward: 7.28125
# Step: 499712	Mean reward: 7.375
# Step: 507904	Mean reward: 8.09375
# Step: 1146880	Mean reward: 8.09375
# Step: 1155072	Mean reward: 9.03125
# Step: 1163264	Mean reward: 10.125
# Step: 1171456	Mean reward: 8.625
# Step: 1179648	Mean reward: 11.46875
# Step: 1187840	Mean reward: 8.03125
# Step: 1196032	Mean reward: 9.75
# Step: 1204224	Mean reward: 10.53125
# Step: 1212416	Mean reward: 10.03125
# Step: 1220608	Mean reward: 9.125
# Step: 1228800	Mean reward: 7.25
# Step: 1236992	Mean reward: 7.625
# Step: 1245184	Mean reward: 7.96875
# Step: 1253376	Mean reward: 10.125
# Step: 1261568	Mean reward: 9.65625
# Step: 1269760	Mean reward: 8.59375
# Step: 1277952	Mean reward: 7.59375
# Step: 1286144	Mean reward: 8.3125
# Step: 1294336	Mean reward: 8.1875
# Step: 1302528	Mean reward: 7.78125
# Step: 1310720	Mean reward: 9.34375
# Step: 1318912	Mean reward: 7.40625
# Step: 1327104	Mean reward: 8.6875
# Step: 1335296	Mean reward: 8.25
# Step: 1343488	Mean reward: 9.6875
# Step: 1351680	Mean reward: 9.53125
# Step: 1359872	Mean reward: 8.625
# Step: 1368064	Mean reward: 8.25
# Step: 1376256	Mean reward: 9.5
# Step: 1384448	Mean reward: 8.8125
# Step: 1392640	Mean reward: 8.5625
# Step: 1400832	Mean reward: 9.03125
# Step: 1409024	Mean reward: 7.9375
# Step: 1417216	Mean reward: 10.03125
# Step: 1425408	Mean reward: 7.75
# Step: 1433600	Mean reward: 9.25
# Step: 1441792	Mean reward: 10.3125
# Step: 1449984	Mean reward: 9.625
# Step: 1458176	Mean reward: 9.1875
# Step: 1466368	Mean reward: 9.46875
# Step: 1474560	Mean reward: 9.3125
# Step: 1482752	Mean reward: 7.84375
# Step: 1490944	Mean reward: 8.5
# Step: 1499136	Mean reward: 8.90625
# Step: 1507328	Mean reward: 10.40625
# Step: 1515520	Mean reward: 9.46875
# Step: 1523712	Mean reward: 8.65625
# Step: 1531904	Mean reward: 9.78125
# Step: 1540096	Mean reward: 10.0
# Step: 1548288	Mean reward: 9.28125
# Step: 1556480	Mean reward: 7.96875
# Step: 1564672	Mean reward: 10.4375
# Step: 1572864	Mean reward: 8.6875
# Step: 1581056	Mean reward: 9.09375
# Step: 1589248	Mean reward: 9.625
# Step: 1597440	Mean reward: 9.25
# Step: 1605632	Mean reward: 9.25
# Step: 1613824	Mean reward: 9.21875
# Step: 1622016	Mean reward: 9.40625
# Step: 1630208	Mean reward: 9.53125
# Step: 1638400	Mean reward: 9.8125
# Step: 1646592	Mean reward: 9.9375
# Step: 1654784	Mean reward: 8.875
# Step: 1662976	Mean reward: 8.40625
# Step: 1671168	Mean reward: 9.84375
# Step: 1679360	Mean reward: 9.5625
# Step: 1687552	Mean reward: 8.71875
# Step: 1695744	Mean reward: 9.375
# Step: 1703936	Mean reward: 10.1875
# Step: 1712128	Mean reward: 10.15625
# Step: 1720320	Mean reward: 9.75
# Step: 1728512	Mean reward: 9.8125
# Step: 1736704	Mean reward: 10.1875
# Step: 1744896	Mean reward: 9.28125
# Step: 1753088	Mean reward: 9.03125
# Step: 1761280	Mean reward: 9.5
# Step: 1769472	Mean reward: 9.8125
# Step: 1777664	Mean reward: 9.59375
# Step: 1785856	Mean reward: 10.125
# Step: 1794048	Mean reward: 8.5625
# Step: 1802240	Mean reward: 9.84375
# Step: 1810432	Mean reward: 8.8125
# Step: 1818624	Mean reward: 9.75
# Step: 1826816	Mean reward: 9.46875
# Step: 1835008	Mean reward: 9.21875
# Step: 1843200	Mean reward: 8.90625
# Step: 1851392	Mean reward: 9.0625
# Step: 1859584	Mean reward: 9.25
# Step: 1867776	Mean reward: 9.5
# Step: 1875968	Mean reward: 9.1875
# Step: 1884160	Mean reward: 9.09375
# Step: 1892352	Mean reward: 9.34375
# Step: 1900544	Mean reward: 9.5625
# Step: 1908736	Mean reward: 8.125
# Step: 1916928	Mean reward: 9.46875
# Step: 1925120	Mean reward: 8.8125
# Step: 1933312	Mean reward: 9.78125
# Step: 1941504	Mean reward: 8.375
# Step: 1949696	Mean reward: 9.46875
# Step: 1957888	Mean reward: 9.8125
# Step: 1966080	Mean reward: 9.90625
# Step: 1974272	Mean reward: 9.6875
# Step: 1982464	Mean reward: 10.59375
# Step: 1990656	Mean reward: 9.34375
# Step: 1998848	Mean reward: 10.0
# Step: 2007040	Mean reward: 9.4375
# Step: 2015232	Mean reward: 9.75
# Step: 2023424	Mean reward: 10.75
# Step: 2031616	Mean reward: 10.5625
# Step: 2039808	Mean reward: 9.9375
# Step: 2048000	Mean reward: 8.375
# Step: 2056192	Mean reward: 10.0
# Step: 2064384	Mean reward: 9.59375
# Step: 2072576	Mean reward: 9.71875
# Step: 2080768	Mean reward: 8.9375
# Step: 2088960	Mean reward: 8.78125
# Step: 2097152	Mean reward: 8.4375
# Step: 2105344	Mean reward: 9.78125
# Step: 2113536	Mean reward: 9.3125
# Step: 2121728	Mean reward: 8.75
# Step: 2129920	Mean reward: 10.03125
# Step: 2138112	Mean reward: 9.6875
# Step: 2146304	Mean reward: 9.09375
# Step: 2154496	Mean reward: 9.28125
# Step: 2162688	Mean reward: 10.34375
# Step: 2170880	Mean reward: 9.65625
# Step: 2179072	Mean reward: 9.96875
# Step: 2187264	Mean reward: 9.9375
# Step: 2195456	Mean reward: 9.34375
# Step: 2203648	Mean reward: 10.15625
# Step: 2211840	Mean reward: 9.25
# Step: 2220032	Mean reward: 8.6875
# Step: 2228224	Mean reward: 8.75
# Step: 2236416	Mean reward: 8.40625
# Step: 2244608	Mean reward: 9.8125
# Step: 2252800	Mean reward: 10.1875
# Step: 2260992	Mean reward: 9.09375
# Step: 2269184	Mean reward: 8.625
# Step: 2277376	Mean reward: 10.03125
# Step: 2285568	Mean reward: 10.34375
# Step: 2293760	Mean reward: 8.46875
# Step: 2301952	Mean reward: 8.21875
# Step: 2310144	Mean reward: 11.34375
# Step: 2318336	Mean reward: 10.125
# Step: 2326528	Mean reward: 9.375
# Step: 2334720	Mean reward: 7.90625
# Step: 2342912	Mean reward: 9.75
# Step: 2351104	Mean reward: 9.59375
# Step: 2359296	Mean reward: 10.21875
# Step: 2367488	Mean reward: 9.1875
# Step: 2375680	Mean reward: 10.21875
# Step: 2383872	Mean reward: 9.46875
# Step: 2392064	Mean reward: 9.59375
# Step: 2400256	Mean reward: 10.0625
# Step: 2408448	Mean reward: 9.75
# Step: 2416640	Mean reward: 10.125
# Step: 2424832	Mean reward: 8.65625
# Step: 2433024	Mean reward: 9.28125
# Step: 2441216	Mean reward: 8.65625
# Step: 2449408	Mean reward: 10.40625
# Step: 2457600	Mean reward: 7.9375
# Step: 2465792	Mean reward: 10.6875
# Step: 2473984	Mean reward: 9.90625
# Step: 2482176	Mean reward: 10.375
# Step: 2490368	Mean reward: 9.46875
# Step: 2498560	Mean reward: 8.75
# Step: 2506752	Mean reward: 9.78125
# Step: 2514944	Mean reward: 8.875
# Step: 2523136	Mean reward: 9.5
# Step: 2531328	Mean reward: 9.59375
# Step: 2539520	Mean reward: 9.25
# Step: 2547712	Mean reward: 9.4375
# Step: 2555904	Mean reward: 8.40625
# Step: 2564096	Mean reward: 10.15625
# Step: 2572288	Mean reward: 9.21875
# Step: 2580480	Mean reward: 9.375
# Step: 2588672	Mean reward: 9.96875
# Step: 2596864	Mean reward: 10.15625
# Step: 2605056	Mean reward: 10.9375
# Step: 2613248	Mean reward: 10.65625
# Step: 2621440	Mean reward: 11.5
# Step: 2629632	Mean reward: 10.125
# Step: 2637824	Mean reward: 10.40625
# Step: 2646016	Mean reward: 9.84375
# Step: 2654208	Mean reward: 11.09375
# Step: 2662400	Mean reward: 8.8125
# Step: 2670592	Mean reward: 9.875
# Step: 2678784	Mean reward: 11.125
# Step: 2686976	Mean reward: 10.1875
# Step: 2695168	Mean reward: 9.15625
# Step: 2703360	Mean reward: 10.625
# Step: 2711552	Mean reward: 10.53125
# Step: 2719744	Mean reward: 10.5
# Step: 2727936	Mean reward: 8.375
# Step: 2736128	Mean reward: 9.3125
# Step: 2744320	Mean reward: 10.71875
# Step: 2752512	Mean reward: 9.78125
# Step: 2760704	Mean reward: 10.34375
# Step: 2768896	Mean reward: 11.59375
# Step: 2777088	Mean reward: 10.8125
# Step: 2785280	Mean reward: 10.59375
# Step: 2793472	Mean reward: 11.21875
# Step: 2801664	Mean reward: 11.1875
# Step: 2809856	Mean reward: 10.21875
# Step: 2818048	Mean reward: 11.1875
# Step: 2826240	Mean reward: 10.875
# Step: 2834432	Mean reward: 11.65625
# Step: 2842624	Mean reward: 11.34375
# Step: 2850816	Mean reward: 11.09375
# Step: 2859008	Mean reward: 11.78125
# Step: 2867200	Mean reward: 11.03125
# Step: 2875392	Mean reward: 10.90625
# Step: 2883584	Mean reward: 10.09375
# Step: 2891776	Mean reward: 11.8125
# Step: 2899968	Mean reward: 12.53125
# Step: 2908160	Mean reward: 11.9375
# Step: 2916352	Mean reward: 10.5
# Step: 2924544	Mean reward: 11.65625
# Step: 2932736	Mean reward: 11.9375
# Step: 2940928	Mean reward: 11.34375
# Step: 2949120	Mean reward: 10.6875
# Step: 2957312	Mean reward: 12.3125
# Step: 5382144	Mean reward: 14.28125
# Step: 5390336	Mean reward: 14.03125
# Step: 5398528	Mean reward: 14.28125
# Step: 5406720	Mean reward: 18.90625
# Step: 5414912	Mean reward: 16.5
# Step: 5423104	Mean reward: 14.65625
# Step: 5431296	Mean reward: 13.84375
# Step: 5439488	Mean reward: 14.25
# Step: 5447680	Mean reward: 16.28125
# Step: 5455872	Mean reward: 15.65625
# Step: 5464064	Mean reward: 14.09375
# Step: 5472256	Mean reward: 14.375
# Step: 5480448	Mean reward: 14.34375
# Step: 5488640	Mean reward: 14.3125
# Step: 5496832	Mean reward: 16.3125
# Step: 5505024	Mean reward: 15.09375
# Step: 5513216	Mean reward: 15.96875
# Step: 5521408	Mean reward: 16.03125
# Step: 5529600	Mean reward: 14.25
# Step: 5537792	Mean reward: 14.3125
# Step: 5545984	Mean reward: 15.0
# Step: 5554176	Mean reward: 13.96875
# Step: 5562368	Mean reward: 16.4375
# Step: 5570560	Mean reward: 16.5625
# Step: 5578752	Mean reward: 15.46875
# Step: 5586944	Mean reward: 14.40625
# Step: 5595136	Mean reward: 15.25
# Step: 5603328	Mean reward: 14.0625
# Step: 5611520	Mean reward: 14.09375
# Step: 5619712	Mean reward: 15.5625
# Step: 5627904	Mean reward: 16.625
# Step: 5636096	Mean reward: 13.84375
# Step: 5644288	Mean reward: 16.34375
# Step: 5652480	Mean reward: 14.78125
# Step: 5660672	Mean reward: 15.375
# Step: 5668864	Mean reward: 15.5
# Step: 5677056	Mean reward: 14.3125
# Step: 5685248	Mean reward: 14.96875
# Step: 5693440	Mean reward: 17.78125
# Step: 5701632	Mean reward: 16.46875
# Step: 5709824	Mean reward: 15.84375
# Step: 5718016	Mean reward: 15.3125
# Step: 5726208	Mean reward: 13.9375
# Step: 5734400	Mean reward: 16.28125
# Step: 5742592	Mean reward: 15.53125
# Step: 5750784	Mean reward: 13.8125
# Step: 5758976	Mean reward: 15.34375
# Step: 5767168	Mean reward: 14.0
# Step: 5775360	Mean reward: 16.125
# Step: 5783552	Mean reward: 16.5
# Step: 5791744	Mean reward: 16.875
# Step: 5799936	Mean reward: 15.1875
# Step: 5808128	Mean reward: 16.875
# Step: 5816320	Mean reward: 15.0
# Step: 5824512	Mean reward: 14.96875
# Step: 5832704	Mean reward: 14.96875
# Step: 5840896	Mean reward: 15.96875
# Step: 5849088	Mean reward: 15.90625
# Step: 5857280	Mean reward: 17.5
# Step: 5865472	Mean reward: 15.4375
# Step: 5873664	Mean reward: 16.0
# Step: 5881856	Mean reward: 13.9375
# Step: 5890048	Mean reward: 15.0625
# Step: 5898240	Mean reward: 16.34375
# Step: 5906432	Mean reward: 17.875
# Step: 5914624	Mean reward: 17.0
# Step: 5922816	Mean reward: 15.46875
# Step: 5931008	Mean reward: 15.15625
# Step: 5939200	Mean reward: 16.71875
# Step: 5947392	Mean reward: 15.125
# Step: 5955584	Mean reward: 15.09375
# Step: 5963776	Mean reward: 14.59375
# Step: 5971968	Mean reward: 14.59375
# Step: 5980160	Mean reward: 14.40625
# Step: 8413184	Mean reward: 15.25
# Step: 8421376	Mean reward: 16.625
# Step: 8429568	Mean reward: 17.625
# Step: 8437760	Mean reward: 15.15625
# Step: 8445952	Mean reward: 14.8125
# Step: 8454144	Mean reward: 16.40625
# Step: 8462336	Mean reward: 17.65625
# Step: 8470528	Mean reward: 16.65625
# Step: 8478720	Mean reward: 14.625
# Step: 8486912	Mean reward: 16.8125
# Step: 8495104	Mean reward: 14.875
# Step: 8503296	Mean reward: 16.9375
# Step: 8511488	Mean reward: 17.0
# Step: 8519680	Mean reward: 16.875
# Step: 8527872	Mean reward: 17.21875
# Step: 8536064	Mean reward: 16.875
# Step: 8544256	Mean reward: 18.0
# Step: 8552448	Mean reward: 15.71875
# Step: 8560640	Mean reward: 15.96875
# Step: 8568832	Mean reward: 15.125
# Step: 8577024	Mean reward: 16.09375
# Step: 8585216	Mean reward: 19.5625
# Step: 8593408	Mean reward: 18.625
# Step: 8601600	Mean reward: 15.6875
# Step: 8609792	Mean reward: 16.71875
# Step: 8617984	Mean reward: 17.84375
# Step: 8626176	Mean reward: 17.28125
# Step: 8634368	Mean reward: 17.71875
# Step: 8642560	Mean reward: 18.0
# Step: 8650752	Mean reward: 17.3125
# Step: 8658944	Mean reward: 17.0
# Step: 8667136	Mean reward: 17.46875
# Step: 8675328	Mean reward: 17.46875
# Step: 8683520	Mean reward: 17.6875
# Step: 8691712	Mean reward: 17.375
# Step: 8699904	Mean reward: 15.75
# Step: 8708096	Mean reward: 16.40625
# Step: 8716288	Mean reward: 17.5625
# Step: 8724480	Mean reward: 17.21875
# Step: 8732672	Mean reward: 14.71875
# Step: 8740864	Mean reward: 15.25
# Step: 8749056	Mean reward: 17.375
# Step: 8757248	Mean reward: 17.3125
# Step: 8765440	Mean reward: 17.0
# Step: 8773632	Mean reward: 15.6875

# %% [markdown]
# Network definitions. We have defined a policy network for you in advance. It uses the popular `NatureDQN` encoder architecture (see below), while policy and value functions are linear projections from the encodings. There is plenty of opportunity to experiment with architectures, so feel free to do that! Perhaps implement the `Impala` encoder from [this paper](https://arxiv.org/pdf/1802.01561.pdf) (perhaps minus the LSTM).

# %% [markdown]
# # New section

# %% [markdown]
# Below cell can be used for policy evaluation and saves an episode to mp4 for you to view.

# %%
import imageio
from google.colab import files

# Make evaluation environment
eval_env = make_env(num_envs, env_name = 'starpilot', use_backgrounds=True,start_level=num_levels, num_levels=num_levels)
obs = eval_env.reset()

frames = []
total_reward = []

# Evaluate policy
policy.eval()
for _ in range(512):

  # Use policy
  action, log_prob, value = policy.act(obs)

  # Take step in environment
  obs, reward, done, info = eval_env.step(action)
  total_reward.append(torch.Tensor(reward))

  # Render environment and store
  frame = (torch.Tensor(eval_env.render(mode='rgb_array'))*255.).byte()
  frames.append(frame)

# Calculate average return
total_reward = torch.stack(total_reward).sum(0).mean(0)
print('Average return:', total_reward)

# Save frames as video
frames = torch.stack(frames)
imageio.mimsave('vid.mp4', frames, fps=25)


files.download('vid.mp4')


#Bossfight
#Step: 8003584	Mean reward: 0.1875
#Completed training!
